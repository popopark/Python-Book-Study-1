# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# 첫번째 파이썬 코드를 실행했습니다.
#
# # 큰 글씨
# 윤하 사랑해요!
#
# ![윤하](https://file2.nocutnews.co.kr/newsroom/image/2022/11/08/202211081104472449_0.jpg)
#
# ## 다음 큰 글씨
#
# ### 다음 더더 큰 글씨

# %%
# 변수 규칙
a = 1
b = 2
a2 = 3  # 변수문은 항상 알파벳으로 시작해야 함

student_count= 100 # 가급적 풀 워드로 짓는다.
address = ''       # 가급적 정확한 영어로 짓는다.

print(a * b, student_count)

print(a * b)
print(a - b)
print(a + b)

print(a2 + b)
# Out:
# 2 100
# 2
# -1
# 3
# 5

# %%
# 대소문자를 구분한다.

friend = 1
Friend = 10

print(friend
# Out:
# 1

# %%
# 숫자형

year = 2023
month = 4
print(year, month)
# Out:
# 2023 4

# %%
year = 2023
print(type(year)) # type() 데이터의 타입을 확인하는 함수

year = '이천이십삼년'
print(type(year))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# 8진수
# 정수 앞에 Oo를 붙이면 8진수

print(0o10)

# 정수 앞에 0b를 붙이면 2진수
# 정수 앞에 0x를 붙이면 16진수

print(0b10)
print(0x10)
# Out:
# 8
# 2
# 16

# %%
# 다음은 10진수를 받아서 각 진수로 변환하는 방법 (결과가 문자형형)

print(type(1))

print(oct(38)) # 10진수 38을 8진수로 변환
print(hex(38)) # 10진수 38을 16진수로 변환
print(bin(38)) # 10진수 38을 2진수로 변환
# Out:
# <class 'int'>
# 0o46
# 0x26
# 0b100110

# %%
# 파이썬의 정수 타입

print(type(1)) # int 타입

print(type(314e-2)) # 2의 31승 int
# Out:
# <class 'int'>
# <class 'float'>

# %%
# 실수의 표현

print(type(3.14))

print(type(314e-2))

print(type(3 - 4j))  # 복소수

x = 3 - 4j

print(x.imag)        # imag는 허수부
print(x.real)        # real는 실수부
print(x.conjugate()) # conjuage는 전체를 확인
# Out:
# <class 'float'>
# <class 'float'>
# <class 'complex'>
# -4.0
# 3.0
# (3+4j)

# %%
# 원의 넓이와 삼각형 넓이 구하기

r = 2

circle_area = (r ** 2) * 3.14
print(circle_area)

x = 3
y = 4
trianagle_area = x * y / 2

print(trianagle_area)
# Out:
# 12.56
# 6.0

# %%
# 문자형 실습

print('Hello world')
print("Hello world")
print("welcome to 'python world'")

print('''

항상 태양을 바라보아라
그리하면 너는 그림자를 볼 수 없을 것이다.

- 헬렌켈러

''')
# Out:
# Hello world
# Hello world
# welcome to 'python world'
#
#
# 항상 태양을 바라보아라
# 그리하면 너는 그림자를 볼 수 없을 것이다.
#
# - 헬렌켈러

# %%
print('\t 탭 \n 다음줄')
# Out:
# 	 탭
#  다음줄

# %%
# 'py' 'thon'

print('py' 'thon')
print('py' + 'thon')
# Out:
# python
# python

# %%
print('py' * 3)
# Out:
# pypypy

# %%
print(a[0])
print(a[0+1])
print(a[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-435b329cc789> in <cell line: 1>()
# ----> 1 print(a[0])
#       2 print(a[0+1])
#       3 print(a[2])
#
# TypeError: 'int' object is not subscriptable

# %%
# index를 이용해서 범위를 설정 할 수 있다.

print(a[0:1])
print(a[1:4])
print(a[:2])
print(a[2:])
print(a[-2:])
print(a[:])
print(a[::2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-ab8fd29cfb3e> in <cell line: 3>()
#       1 # index를 이용해서 범위를 설정 할 수 있다.
#       2
# ----> 3 print(a[0:1])
#       4 print(a[1:4])
#       5 print(a[:2])
#
# TypeError: 'int' object is not subscriptable

# %%
# 데이터 타입의 변환

print(str(3.14))    # 문자형으로 변환
print(int('49'))    # 정수형으로 변환환
print(float(23))    # 실수형으로 변환
# Out:
# 3.14
# 49
# 23.0
